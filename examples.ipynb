# %%
import numpy as np
import matplotlib as plt
import importlib
import knihovna.hledani
import knihovna.generovani
importlib.reload(knihovna.generovani)
importlib.reload(knihovna.hledani)
from knihovna.hledani import Bludiste
from knihovna.hledani import nacti_data
from knihovna.hledani import vykresli_cestu
from knihovna.hledani import najdi_cestu
from knihovna.generovani import zmena_policek
from knihovna.generovani import over_cestu
from knihovna.generovani import obrazek_bludiste

data = nacti_data("data/maze_4.csv")
bludiste = Bludiste(data)
najdi_cestu(bludiste.parametry)

# %%
data = nacti_data("data/maze_2.csv")
bludiste = Bludiste(data)
najdi_cestu(bludiste.parametry)

# %%
nalezeno = False
bludiste = nacti_data("sablony/prazdna.csv")
while not nalezeno:
    bludiste = nacti_data("sablony/prazdna.csv")
    zmena_policek(bludiste,20)
    nalezeno = over_cestu(bludiste)
najdi_cestu(bludiste)

# %%
nalezeno = False
bludiste = nacti_data("sablony/had.csv")
while not nalezeno:
    bludiste = nacti_data("sablony/had.csv")
    zmena_policek(bludiste,20)
    nalezeno = over_cestu(bludiste)
najdi_cestu(bludiste)
